# %%
Hardware:Physical parts of a computer that you can see and touch
Example:Keyboard(used to type input into the computer)
Software:Programs or instructions that tell the hardware what to do0
Example:Windows Operating system(controls and manages computer operations)
